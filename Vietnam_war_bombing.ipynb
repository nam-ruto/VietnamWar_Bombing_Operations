# %%
## Vietnam war bombing operation

# %%
import pandas as pd
import numpy as num
import matplotlib.pyplot as plt
import folium
from folium.plugins import FastMarkerCluster
from mpl_toolkits.basemap import Basemap
import plotly.express as px

# %%
# Read and fillter data
data = pd.read_csv("./data/THOR_Vietnam_Bombing_Operations.csv", encoding="latin-1", usecols=["MSNDATE", "TGTLATDD_DDD_WGS84", "TGTLONDDD_DDD_WGS84", "AIRCRAFT_ORIGINAL"])
data = data.sort_values(["MSNDATE"])
data = data.iloc[:15000]
# data.head()

# %%
longd = data["TGTLONDDD_DDD_WGS84"]
latd = data["TGTLATDD_DDD_WGS84"]
coor = list(zip(latd, longd))

# %%
# fig = px.scatter(data, x="TGTLONDDD_DDD_WGS84", y="TGTLATDD_DDD_WGS84")
# fig = px.scatter_mapbox(data, lat="TGTLATDD_DDD_WGS84", lon="TGTLONDDD_DDD_WGS84", color_discrete_sequence=px.colors.qualitative.Pastel)
fig = px.scatter_mapbox(data, lat="TGTLATDD_DDD_WGS84", lon="TGTLONDDD_DDD_WGS84", color_continuous_scale=px.colors.sequential.Hot, color_discrete_sequence=["red"])
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(autosize=False, width=1000, height=800)
fig.show()
